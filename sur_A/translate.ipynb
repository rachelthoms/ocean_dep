# %%
OPENAI_API_KEY="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"

import subprocess as sp

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from zipfile import ZipFile
import os

# %%
# unzipping survey tables

# specifying location of .zip and extraction location
sur_A_path="/home/rthoms/ocean_dep/sur_A/raw_data/Sur_A_26072023.zip"
sur_A_raw="/home/rthoms/ocean_dep/sur_A/raw_data/sur_A_raw"

# loading the .zip and creating a zip object
with ZipFile(sur_A_path, 'r') as zObject:

	# Extracting all the members of the zip
	# into a the specified location.
	zObject.extractall(
		path=sur_A_raw)

# %%
ev_raw = os.path.join(sur_A_raw, "Ecological Vulnerability Data Entry_0.csv")
df_ev = pd.read_csv(ev_raw)

df_ev.columns
# Out:
# Index(['objectid', 'globalid', 'id', 'date', 'ccp', 'seagrass_quality_change',
#        'sg_quality_change_note', 'seagrass_quantity_change',
#        'sg_quantity_change_note', 'causes_seagrass_change', 'sg_causes_coded',
#        'focal_resources', 'sg_dependence_note', 'resource_quality_change_note',
#        'resource_quantity_change_note', 'management_note', 'compliance_note',
#        'resource_change_note', 'resource_change_note.1', 'note', 'review_flag',
#        'CreationDate', 'Creator', 'EditDate', 'Editor', 'x', 'y'],
#       dtype='object')

# %%
df_ev = df_ev.head(3)

def translate (column_val):
   command = 'export OPENAI_API_KEY="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";opentranslator  --translate english --text "{value}"'
   output = sp.getoutput(command.format(value=column_val))
   return output

col_to_trans = [col for col in df_ev.columns if 'note' in col]

for col in col_to_trans:
   new_col_name = str(col)+"_trans"
   df_ev[new_col_name] = df_ev.apply(lambda row : None if pd.isnull(row[col]) else translate(row[col]), axis = 1)
   
df_ev.head()
# Out:
#    objectid                              globalid              id  \
# 0         2  b6f6afb4-7c5a-44a1-97d5-74482f766527  05032023JOSA01
# 1         3  2f7b61dd-e0c8-47f0-9c0b-9879a3cee5a1  04022023CHAA01
# 2         4  4936c582-ca79-48b3-8919-e4ab7dbb035d  18022023ILHA01
#
#                     date            ccp seagrass_quality_change  \
# 0   5/8/2023 10:00:00 AM  josina_machel               sig_worse
# 1   5/8/2023 10:00:00 AM        chamane               no_change
# 2  5/20/2023 10:00:00 AM           ilha               sig_worse
#
#                               sg_quality_change_note seagrass_quantity_change  \
# 0  Ervas secaram e sairam. O tamanho  reduziu_se ...                 sig_less
# 1  Nao ha mudanca, as eravas ce antiguidade eram ...                 sig_less
# 2  O vendaval de 2017, fez com que houvesse a dev...                 sig_less
#
#                              sg_quantity_change_note  \
# 0  Afecta pirony, gywindrituno, kelegele perderam...
# ...

# %%
df_ev.to_csv('com_eco_sens_cleaned.csv')
