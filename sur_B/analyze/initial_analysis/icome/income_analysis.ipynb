# %% [markdown]
# # Analyzing income
# The purpose of this notebook is to investigate the various ways we can measure income from surveys B and C

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from zipfile import ZipFile
import os
import seaborn as sns
from autoviz import data_cleaning_suggestions

pd.options.mode.chained_assignment = None

# %%
# specifiy location of data
df = pd.read_csv("/home/rthoms/ocean_dep/sur_B/capture_table_clean.csv")
df = df[['id','ccp', 'gender', 'fish_pract', 'pract_cat', 
        'focal_resource','prop_cap_hot', 'prop_cap_cold', 'days_hot', 'days_cold',
        'cap_daily_hot', 'cap_daily_cold', 'cap_monthly_hot',
        'cap_monthly_cold', 'cap_income_hot', 'cap_income_cold',
        'val_trade_hot', 'val_trade_cold', 'activity_income_hot',
        'activity_income_cold', 'income_fr_hot', 'income_fr_cold',
        'tot_income_hot', 'tot_income_cold', 'prop_income_hot',
        'prop_income_cold',]]

# %%
print(f"There are {len(df)} rows and {len(df.columns)} columns in dataframe.")
# Out:
# There are 269 rows and 26 columns in dataframe.

# %%
data_cleaning_suggestions(df)
# Out:
# <style type="text/css">
# ...
